# %% [markdown]
# This notebook show how to open the .h5 files that contain instrument data (waveforms) and metadata for each event.

# %%
import h5py
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ls
# Out:
# earthquake_sample_events.h5  plot_events.ipynb      using_obspy.ipynb
# explosion_sample_events.h5   prep_data_for_tord.py

# %% [markdown]
# Each file contains two HDF5 datasets, which are accessed by name:
#  - 'event_info', an array of JSON strings, where element has info about the location, type, etc of the event
#  - 'traces', an array of numpy arrays, of shape (num events, num waveforms, waveform length)

# %%
with h5py.File('earthquake_sample_events.h5', 'r') as fin:
    event_info_dataset = fin.get('event_info')
    trace_dataset = fin.get('traces')
    
    # Convert to numpy arrays
    eq_event_info = np.array(event_info_dataset)
    eq_trace_data = np.array(trace_dataset)

print(f'Loaded {eq_event_info.shape[0]} earthquake events')
# Out:
# Loaded 152 earthquake events

# %% [markdown]
# 'event_info' contains JSON strings, which can be imported as python dicts. Let's look at the first one:

# %%
event_info_dict = json.loads(eq_event_info[0])
print(json.dumps(event_info_dict, indent=2))
# Out:
# {
#   "resource_id": "smi:local/5618a40f-8a92-40b1-93e8-3f99ba83f3f0",
#   "event_type": "earthquake",
#   "event_type_certainty": "known",
#   "picks": [
#     {
#       "resource_id": "smi:local/618f3c22-131c-496e-9ff4-352cf9f97b15",
#       "time": "2019-01-08T17:15:20.610000Z",
#       "waveform_id": {
#         "station_code": "KIF",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Lg"
#     },
#     {
#       "resource_id": "smi:local/708ac890-f7b2-4151-adcb-d2e86fd686da",
#       "time": "2019-01-08T17:14:59.240000Z",
#       "waveform_id": {
#         "station_code": "KIF",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pn"
#     },
#     {
#       "resource_id": "smi:local/4b7cbe12-96df-481b-9a6b-00b8e89d16ea",
#       "time": "2019-01-08T17:14:54.260000Z",
#       "waveform_id": {
#         "station_code": "TRO",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Lg"
#     },
#     {
#       "resource_id": "smi:local/32fc9812-ab2f-41a5-9748-29b5aadf0706",
#       "time": "2019-01-08T17:14:44.280000Z",
#       "waveform_id": {
#         "station_code": "TRO",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pg"
#     },
#     {
#       "resource_id": "smi:local/e735b533-4149-4c4c-b4d4-e5e53e7f1f9c",
#       "time": "2019-01-08T17:15:10.550000Z",
#       "waveform_id": {
#         "station_code": "JETT",
#         "channel_code": "BHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Lg"
#     },
#     {
#       "resource_id": "smi:local/951a2055-d65c-42cc-b071-698471a5cb13",
#       "time": "2019-01-08T17:14:53.325000Z",
#       "waveform_id": {
#         "station_code": "JETT",
#         "channel_code": "BHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pg"
#     },
#     {
#       "resource_id": "smi:local/f1cc2044-ec12-496b-9511-45713338ed0c",
#       "time": "2019-01-08T17:15:12.540000Z",
#       "waveform_id": {
#         "station_code": "KTK1",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pg"
#     },
#     {
#       "resource_id": "smi:local/0cc872f6-a0cc-4604-ae4a-9cf12139920d",
#       "time": "2019-01-08T17:15:57.530000Z",
#       "waveform_id": {
#         "station_code": "HEF",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Lg"
#     },
#     {
#       "resource_id": "smi:local/a28937ed-f29c-4ba4-9bf1-4e7a0c10f94c",
#       "time": "2019-01-08T17:15:49.990000Z",
#       "waveform_id": {
#         "station_code": "HEF",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Sn"
#     },
#     {
#       "resource_id": "smi:local/87d19f4d-9a72-4ce2-9062-4be1880f021b",
#       "time": "2019-01-08T17:15:21.390000Z",
#       "waveform_id": {
#         "station_code": "HEF",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pg"
#     },
#     {
#       "resource_id": "smi:local/d84338af-28a5-4e4a-b0cd-7f5f443884b2",
#       "time": "2019-01-08T17:15:16.200000Z",
#       "waveform_id": {
#         "station_code": "HEF",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pn"
#     },
#     {
#       "resource_id": "smi:local/4b9c035f-d28a-47d6-a7a5-8b8fb57886d7",
#       "time": "2019-01-08T17:15:44.130000Z",
#       "waveform_id": {
#         "station_code": "KTK1",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Lg"
#     },
#     {
#       "resource_id": "smi:local/83634750-f6ad-43d9-8375-465d6b38c808",
#       "time": "2019-01-08T17:15:10.020000Z",
#       "waveform_id": {
#         "station_code": "KTK1",
#         "channel_code": "HHZ"
#       },
#       "horizontal_slowness": -1.0,
#       "horizontal_slowness_errors": {
#         "uncertainty": -1.0
#       },
#       "backazimuth": -1.0,
#       "backazimuth_errors": {
#         "uncertainty": -1.0
#       },
#       "phase_hint": "Pn"
#     },
#     {
#       "resource_id": "smi:local/7a461691-60fb-408c-a771-23463c2695e8",
#       "time": "2019-01-08T17:15:17.825000Z",
#       "waveform_id": {
#         "station_code": "ARCES",
#         "channel_code": "FG34"
#       },
#       "horizontal_slowness": 10.552729,
#       "horizontal_slowness_errors": {
#         "uncertainty": 0.948436
#       },
#       "backazimuth": 289.98311,
#       "backazimuth_errors": {
#         "uncertainty": 5.151246
#       },
#       "phase_hint": "Pn"
#     },
#     {
#       "resource_id": "smi:local/57092f30-8258-49ea-bba6-25f3564458ec",
#       "time": "2019-01-08T17:15:23.000000Z",
#       "waveform_id": {
#         "station_code": "ARCES",
#         "channel_code": "FD19"
#       },
#       "horizontal_slowness": 26.25442,
#       "horizontal_slowness_errors": {
#         "uncertainty": 1.861278
#       },
#       "backazimuth": 285.9454,
#       "backazimuth_errors": {
#         "uncertainty": 4.062772
#       },
#       "phase_hint": "Pg"
#     },
#     {
#       "resource_id": "smi:local/87cf8526-5d58-44fa-9a4d-80c621454a4f",
#       "time": "2019-01-08T17:16:02.100000Z",
#       "waveform_id": {
#         "station_code": "ARCES",
#         "channel_code": "FT22"
#       },
#       "horizontal_slowness": 26.207938,
#       "horizontal_slowness_errors": {
#         "uncertainty": 1.2834
#       },
#       "backazimuth": 273.94519,
#       "backazimuth_errors": {
#         "uncertainty": 2.806048
#       },
#       "phase_hint": "Lg"
#     }
#   ],
#   "origins": [
#     {
#       "resource_id": "smi:local/14373b74-2b29-442f-a6db-1576b9abf765",
#       "time": "2019-01-08T17:14:30.717560Z",
#       "time_errors": {
#         "uncertainty": 3.8820186
#       },
#       "longitude": 17.434093,
#       "latitude": 70.114655,
#       "depth": 4.6603138,
#       "depth_errors": {
#         "uncertainty": 19.367055
#       },
#       "quality": {
#         "associated_phase_count": 16,
#         "used_phase_count": 16
#       },
#       "creation_info": {
#         "agency_id": "NORSAR",
#         "author": "ARS:berit",
#         "creation_time": "2019-01-22T15:07:46.000000Z"
#       },
#       "comments": [
#         {
#           "text": "orid: 21965",
#           "resource_id": "smi:local/e6d6771b-628e-408f-b968-671a11e85616"
#         }
#       ],
#       "arrivals": [
#         {
#           "resource_id": "smi:local/871b0f7d-4088-49a9-9ba4-7734050b33b9",
#           "pick_id": "smi:local/618f3c22-131c-496e-9ff4-352cf9f97b15",
#           "phase": "Lg",
#           "azimuth": 313.88791,
#           "time_residual": -0.85279273,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73458",
#               "resource_id": "smi:local/4ce0dbf7-5f8c-4410-9c2e-97979111a611"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/8b0f8d50-fa5b-4ce0-94d8-455caf609677",
#           "pick_id": "smi:local/708ac890-f7b2-4151-adcb-d2e86fd686da",
#           "phase": "Pn",
#           "azimuth": 313.88791,
#           "time_residual": -0.42147584,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73459",
#               "resource_id": "smi:local/8c45916f-a047-405c-988d-fa3d36053bc0"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/7cd9b99f-05fc-4de4-8f1b-b71057b5d2d9",
#           "pick_id": "smi:local/4b7cbe12-96df-481b-9a6b-00b8e89d16ea",
#           "phase": "Lg",
#           "azimuth": 314.10713,
#           "time_residual": 0.20981202,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73460",
#               "resource_id": "smi:local/39c0d8ac-4e5f-4d18-ae55-be393103bc66"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/0524f93f-1dfe-4ff7-a2c9-251964bd9b7f",
#           "pick_id": "smi:local/32fc9812-ab2f-41a5-9748-29b5aadf0706",
#           "phase": "Pg",
#           "azimuth": 314.10713,
#           "time_residual": 0.070040082,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73461",
#               "resource_id": "smi:local/31e9b8ae-45fc-43a3-9427-94b980bcfb6c"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/edc54282-08db-4671-b27e-668e0468238e",
#           "pick_id": "smi:local/e735b533-4149-4c4c-b4d4-e5e53e7f1f9c",
#           "phase": "Lg",
#           "azimuth": 299.95908,
#           "time_residual": 1.4295828,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73462",
#               "resource_id": "smi:local/d2f6adaf-0c70-456c-a8db-d24a9bbc8a23"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/daa25283-84ae-470f-a9f6-b42e120d450d",
#           "pick_id": "smi:local/951a2055-d65c-42cc-b071-698471a5cb13",
#           "phase": "Pg",
#           "azimuth": 299.95908,
#           "time_residual": -0.10809466,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73463",
#               "resource_id": "smi:local/68f18cde-2781-4f15-9272-587d256af391"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/b0fd8a3d-edb0-4e59-99db-faab38c77b1e",
#           "pick_id": "smi:local/f1cc2044-ec12-496b-9511-45713338ed0c",
#           "phase": "Pg",
#           "azimuth": 301.2371,
#           "time_residual": -0.47318571,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73464",
#               "resource_id": "smi:local/e17fd9f6-5703-4bb8-aa05-b82c91ad51df"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/c71f1e58-6861-46f4-8a8d-09c63f1225db",
#           "pick_id": "smi:local/0cc872f6-a0cc-4604-ae4a-9cf12139920d",
#           "phase": "Lg",
#           "azimuth": 310.61329,
#           "time_residual": -2.2990746,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73465",
#               "resource_id": "smi:local/66f5b7c8-9e05-4cb6-b3a7-464a9ac52d97"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/a4c0fea3-2797-4eab-b58a-45e9eb53e0e8",
#           "pick_id": "smi:local/a28937ed-f29c-4ba4-9bf1-4e7a0c10f94c",
#           "phase": "Sn",
#           "azimuth": 310.61329,
#           "time_residual": -1.3329718,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73466",
#               "resource_id": "smi:local/1bae1101-ea10-4983-9864-bd1ad4f93ecd"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/cf5718ba-8476-4d9b-a7e2-e585beabec67",
#           "pick_id": "smi:local/87d19f4d-9a72-4ce2-9062-4be1880f021b",
#           "phase": "Pg",
#           "azimuth": 310.61329,
#           "time_residual": -0.46221154,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73467",
#               "resource_id": "smi:local/95a5b466-70d3-404e-86dc-f38d6d421126"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/236e4aef-d706-4cb7-a4bf-238aa5839fab",
#           "pick_id": "smi:local/d84338af-28a5-4e4a-b0cd-7f5f443884b2",
#           "phase": "Pn",
#           "azimuth": 310.61329,
#           "time_residual": 0.010682581,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73468",
#               "resource_id": "smi:local/545d0edc-75e4-4174-8894-e123b595a734"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/110bad9a-8a5e-47a3-a5a2-5a736fd2700a",
#           "pick_id": "smi:local/4b9c035f-d28a-47d6-a7a5-8b8fb57886d7",
#           "phase": "Lg",
#           "azimuth": 301.2371,
#           "time_residual": -0.33151845,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73469",
#               "resource_id": "smi:local/6bfc7dcc-a3d3-4600-82c6-22db107c99d3"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/0beb2d5a-14af-46aa-bdbb-c229314a4c92",
#           "pick_id": "smi:local/83634750-f6ad-43d9-8375-465d6b38c808",
#           "phase": "Pn",
#           "azimuth": 301.2371,
#           "time_residual": 0.49202915,
#           "horizontal_slowness_residual": -999.0,
#           "backazimuth_residual": -999.0,
#           "comments": [
#             {
#               "text": "ARID=73470",
#               "resource_id": "smi:local/0f5d3750-6139-46ac-9930-ded961f0d8a3"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/6a4ca37f-b461-4353-937b-ed83ee64f322",
#           "pick_id": "smi:local/7a461691-60fb-408c-a771-23463c2695e8",
#           "phase": "Pn",
#           "azimuth": 285.52183,
#           "time_residual": 0.88618658,
#           "horizontal_slowness_residual": -3.1984097,
#           "backazimuth_residual": 4.4612766,
#           "comments": [
#             {
#               "text": "ARID=7014788",
#               "resource_id": "smi:local/fdb0c6cb-ad0d-4649-b00f-40c3d087e93b"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/5354b2cd-46b8-4f84-9e02-7c8edc15cc6e",
#           "pick_id": "smi:local/57092f30-8258-49ea-bba6-25f3564458ec",
#           "phase": "Pg",
#           "azimuth": 285.52183,
#           "time_residual": 0.15583548,
#           "horizontal_slowness_residual": 8.0277564,
#           "backazimuth_residual": 0.42356657,
#           "comments": [
#             {
#               "text": "ARID=7014790",
#               "resource_id": "smi:local/fc833442-9ffd-4021-8e6b-15fe1262264e"
#             }
#           ]
#         },
#         {
#           "resource_id": "smi:local/c58b43a2-3879-4bbc-bed7-c16b48f47c70",
#           "pick_id": "smi:local/87cf8526-5d58-44fa-9a4d-80c621454a4f",
#           "phase": "Lg",
#           "azimuth": 285.52183,
#           "time_residual": 0.54049387,
#           "horizontal_slowness_residual": -5.5896008,
#           "backazimuth_residual": -11.576643,
#           "comments": [
#             {
#               "text": "ARID=7014797",
#               "resource_id": "smi:local/efc530b5-192c-4987-9580-7e8fcc49efd0"
#             }
#           ]
#         }
#       ]
#     }
#   ],
#   "magnitudes": [
#     {
#       "resource_id": "smi:local/0cf35f13-cd6b-4e05-af5c-4f536597ffcd",
#       "mag": 1.525,
#       "magnitude_type": "Mb",
#       "origin_id": "smi:local/14373b74-2b29-442f-a6db-1576b9abf765"
#     },
#     {
#       "resource_id": "smi:local/932b5e8f-5a4c-4319-bb7c-e119fefff288",
#       "mag": -9.99,
#       "magnitude_type": "Ml",
#       "origin_id": "smi:local/14373b74-2b29-442f-a6db-1576b9abf765"
#     }
#   ],
#   "az_to_arces": 98.03400862061639,
#   "baz_to_arces": 285.61586895410187,
#   "dist_to_arces": 317.52773873591445,
#   "az_to_spits": 358.4463196997784,
#   "baz_to_spits": 177.4201535228992,
#   "dist_to_spits": 900.7066473978686,
#   "rating": "ok",
#   "trace_stats": {
#     "starttime": "2019-01-08T17:15:19.575000Z",
#     "sampling_rate": 40.0,
#     "station": "ARA0",
#     "channels": [
#       "BHE",
#       "BHN",
#       "BHZ"
#     ]
#   }
# }

# %% [markdown]
# There is a lot of info here, but the important fields are

# %%
print('Event type: {} {}'.format(event_info_dict['event_type_certainty'], event_info_dict['event_type']))
print('Event time and location: {}, {}N {}E'.format(
    event_info_dict['origins'][0]['time'],
    event_info_dict['origins'][0]['latitude'],
    event_info_dict['origins'][0]['longitude'],
))
# Out:
# Event type: known earthquake
# Event time and location: 2019-01-08T17:14:30.717560Z, 70.114655N 17.434093E

# %% [markdown]
# We can now plot the traces (waveforms) of this event

# %%
traces = eq_trace_data[0]
print('{} traces, {} time points per trace'.format(traces.shape[0], traces.shape[1]))
# Out:
# 3 traces, 4801 time points per trace

# %%
# make a simple plot
fig, axs = plt.subplots(3, 1, sharex=True)
xvals = list(range(len(traces[0])))
for i in range(3):
    axs[i].plot(xvals, traces[i])

# %% [markdown]
# The events data looks a bit useless, but this is because we are looking at raw, unfiltered data. The _Obspy_ library has a lot of useful routines for signal processing, shown in the 'using-obspy' notebook

# %%
# Same but for explosions
with h5py.File('explosion_sample_events.h5', 'r') as fin:
    event_info_dataset = fin.get('event_info')
    trace_dataset = fin.get('traces')
    
    ex_event_info = np.array(event_info_dataset)
    ex_trace_data = np.array(trace_dataset)

print(f'Loaded {ex_event_info.shape[0]} explosion events')
# Out:
# Loaded 198 explosion events

# %% [markdown]
# For explosion events, there is typically extra info listed as 'comments', containing the name of the mine where the explosion took place.

# %%
event_info_dict = json.loads(ex_event_info[0])

print('Event type: {} {}'.format(event_info_dict['event_type_certainty'], event_info_dict['event_type']))
for comment in event_info_dict['comments']:
    print(comment['text'])
# Out:
# Event type: known explosion
# FULLY AUTOMATIC, EVENT TYPE & LOCATION & MAGNITUDE CHECKED (LEV)
# MINING AREA: KEVITSA  3KM
